# %%
# https://www.amazon.science/blog?q=&f0=0000016e-2ff0-da81-a5ef-3ff057f10000&s=1&expandedFilters=Research%2520area%2CTag%2CTag%2CTag%2CTag%2CTag%2CTag%2CTag%2CTag%2CTag%2CTag%2CTag%2CTag%2CTag%2CTag%2CTag%2CTag%2CTag%2CTag%2CTag%2CTag%2CTag%2CTag%2CConference%2CConference%2CConference%2CConference%2CConference%2CConference%2CConference%2CConference%2CConference%2CConference%2CConference%2CConference%2CConference%2CAuthor%2CAuthor%2CAuthor%2CAuthor%2CAuthor%2CAuthor%2CAuthor%2CAuthor%2CAuthor%2CAuthor%2CAuthor%2CAuthor%2CAuthor%2CAuthor%2CAuthor%2CAuthor%2CAuthor%2CAuthor%2CAuthor%2CAuthor%2CAuthor%2CAuthor%2CDate%2C
import re
from bs4 import BeautifulSoup
from urllib.parse import urlparse
import requests

def fetch_html(url):
    headers = {"User-Agent": "Mozilla/5.0"}
    response = requests.get(url, headers=headers)
    
    if response.status_code != 200:
        print(response.status_code)
        return ""

    html = response.text
    return html

# %%
url = "https://www.anthropic.com/research"

# %%
html = fetch_html(url)

# %%
html
# Out:
# '<!DOCTYPE html><html lang="en" class="__variable_42f43f __variable_403256 __variable_57fc85 __variable_34e0db"><head><meta charSet="utf-8"/><meta name="viewport" content="width=device-width, initial-scale=1"/><link rel="preload" href="/_next/static/media/844eb89fa4effbb2-s.p.woff2" as="font" crossorigin="" type="font/woff2"/><link rel="preload" href="/_next/static/media/8e81091e64ffbb65-s.p.woff2" as="font" crossorigin="" type="font/woff2"/><link rel="preload" href="/_next/static/media/afcde17c90040887-s.p.woff2" as="font" crossorigin="" type="font/woff2"/><link rel="preload" href="/_next/static/media/c1cf232a330ed002-s.p.woff2" as="font" crossorigin="" type="font/woff2"/><link rel="preload" href="/_next/static/media/cfe503504e29ad5d-s.p.woff2" as="font" crossorigin="" type="font/woff2"/><link rel="preload" href="/_next/static/media/d7440d3c533a1aec-s.p.woff2" as="font" crossorigin="" type="font/woff2"/><link rel="preload" href="/_next/static/media/db2277a4dc542e54-s.p.woff2" as="fo
# ...

# %%
# text_to_find = "title"
text_to_find = "Publications"
result = soup.find(string=lambda text: text_to_find in text)

# %%
script_tag = result.parent
script_tag
# Out:
# <script nonce="NGY4MzkyYzktNWIyZC00M2FhLWFlMTctOGQ0MDhkY2I3ODcw">self.__next_f.push([1,"1c:[\"$\",\"$L26\",null,{\"page\":{\"_type\":\"page\",\"_updatedAt\":\"2024-06-20T14:51:58Z\",\"_id\":\"b5e6b6d0-f668-4312-8a00-0e804343be62\",\"meta\":null,\"_rev\":\"8Ka5T868moynofPrGLUbQN\",\"title\":\"Research\",\"slug\":{\"current\":\"research\",\"_type\":\"slug\"},\"_createdAt\":\"2024-03-09T15:23:03Z\",\"sections\":[{\"backgroundImage\":null,\"flushBottom\":false,\"_updatedAt\":\"2024-11-06T16:05:28Z\",\"_rev\":\"CElEURHSNPsNPOAGkswuuV\",\"bodyWidth\":\"normal\",\"ctas\":[{\"_type\":\"link\",\"text\":\"See open roles\",\"fileAsset\":null,\"_createdAt\":\"2024-05-15T20:27:24Z\",\"_rev\":\"FmCcXsQk43sjGP4TKXBCp8\",\"_id\":\"c342e3be-1bae-4d1d-b594-bf3f9095fe08\",\"_updatedAt\":\"2024-06-20T14:51:22Z\",\"url\":\"https://www.anthropic.com/jobs?team=4002061008\",\"page\":null,\"modalId\":null}],\"titleAlternative\":\"Researching \\nat the frontier\",\"_type\":\"heroCta\",\"_id\":\"fe5e453b-ae1a-
# %%
import re
import json

# Your existing pattern
pattern = r'{\\"current\\":\\"([^"\\]+)\\",\\"_type\\":\\"slug\\"},\\"title\\":\\"([^"\\]+)\\",\\"cta\\":{\\"_type\\":\\"link\\",\\"text\\":\\"([^"\\]+)\\",\\"url\\":\\"([^"\\]+)\\"}}' 

# The JSON string with escaped backslashes
json_string = """{\\"_updatedAt\\":\\"2024-11-06T16:10:49Z\\",\\"initialView\\":\\"list\\",\\"internalName\\":\\"Research\\",\\"showSearch\\":true,\\"_type\\":\\"postList\\",\\"flushBottom\\":true,\\"directory\\":{\\"label\\":\\"Research\\",\\"_key\\":\\"research\\",\\"value\\":\\"research\\",\\"_type\\":\\"tag\\"},\\"_createdAt\\":\\"2023-12-21T03:32:31Z\\",\\"_rev\\":\\"CElEURHSNPsNPOAGksxZAd\\",\\"_id\\":\\"1285aca9-4ef8-44f8-b176-f18c40b61808\\",\\"title\\":\\"Publications\\",\\"flushTop\\":false,\\"postSubjects\\":null,\\"posts\\":[{\\"_type\\":\\"post\\",\\"cardPhoto\\":null,\\"publishedOn\\":\\"2025-03-13T16:00:00.000Z\\",\\"directories\\":[{\\"_type\\":\\"tag\\",\\"label\\":\\"Research\\",\\"_key\\":\\"research\\",\\"value\\":\\"research\\"}],\\"subjects\\":[{\\"_type\\":\\"tag\\",\\"label\\":\\"Alignment\\",\\"_key\\":\\"alignment\\",\\"value\\":\\"alignment\\"},{\\"_key\\":\\"interpretability\\",\\"value\\":\\"interpretability\\",\\"_type\\":\\"tag\\",\\"label\\":\\"Interpretability\\"}],\\"slug\\":{\\"current\\":\\"auditing-hidden-objectives\\",\\"_type\\":\\"slug\\"},\\"title\\":\\"Auditing language models for hidden objectives\\",\\"cta\\":{\\"_type\\":\\"link\\",\\"text\\":\\"Read the paper\\",\\"url\\":\\"https://assets.anthropic.com/m/317564659027fb33/original/Auditing-Language-Models-for-Hidden-Objectives.pdf\\"}},{\\"title\\":\\"Forecasting rare language model behaviors\\",\\"cta\\":{\\"_type\\":\\"link\\",\\"text\\":\\"Read the paper\\",\\"url\\":\\"https://arxiv.org/abs/2502.16797\\"},\\"_type\\":\\"post\\",\\"cardPhoto\\":null,\\"publishedOn\\":\\"2025-02-25T20:17:00.000Z\\",\\"directories\\":[{\\"value\\":\\"research\\",\\"_type\\":\\"tag\\",\\"label\\":\\"Research\\",\\"_key\\":\\"research\\"}],\\"subjects\\":[{\\"label\\":\\"Alignment\\",\\"_key\\":\\"alignment\\",\\"value\\":\\"alignment\\",\\"_type\\":\\"tag\\"}],\\"slug\\":{\\"current\\":\\"forecasting-rare-behaviors\\",\\"_type\\":\\"slug\\"}},{\\"cta\\":null,\\"_type\\":\\"post\\",\\"cardPhoto\\":{\\"description\\":\\"A hand-drawn image of a hand with a set of nodes emerging above it, extending in several different directions\\",\\"height\\":1260,\\"url\\":\\"https://cdn.sanity.io/images/4zrzovbb/website/35c3cf6f17013234144a4065dfd8b7d876521be1-1680x1260.png\\",\\"width\\":1680},\\"publishedOn\\":\\"2025-02-24T14:38:00.000Z\\",\\"directories\\":[{\\"label\\":\\"Research\\",\\"_key\\":\\"research\\",\\"value\\":\\"research\\",\\"_type\\":\\"tag\\"},{\\"_type\\":\\"tag\\",\\"label\\":\\"News\\",\\"_key\\":\\"news\\",\\"value\\":\\"news\\"}],\\"subjects\\":[{\\"label\\":\\"Announcements\\",\\"_key\\":\\"announcements\\",\\"value\\":\\"announcements\\",\\"_type\\":\\"tag\\"}],\\"slug\\":{\\"_type\\":\\"slug\\",\\"current\\":\\"visible-extended-thinking\\"},\\"title\\":\\"Claude's extended thinking\\"},{\\"cta\\":{\\"_type\\":\\"link\\",\\"text\\":\\"Read Transformer Circuits\\",\\"url\\":\\"https://transformer-circuits.pub/2025/crosscoder-diffing-update/index.html\\"}}]}"""

# First, unescape the backslashes to get a proper JSON string
unescaped_json = json_string.replace('\\"', '"')

# Parse the JSON string into a Python dictionary
data = json.loads(unescaped_json)

# Now you can access the data
print(f"Title: {data['title']}")
print(f"Number of posts: {len(data['posts'])}")

# You can also access specific posts
# for i, post in enumerate(data['posts']):
#     print(f"\nPost {i+1}: {post['title']}")
#     if post['cta'] and 'url' in post['cta']:
#         print(f"URL: {post['cta']['url']}")
# Out:
# Title: Publications
# Number of posts: 4

# %%
data
# Out:
# {'_updatedAt': '2024-11-06T16:10:49Z',
#  'initialView': 'list',
#  'internalName': 'Research',
#  'showSearch': True,
#  '_type': 'postList',
#  'flushBottom': True,
#  'directory': {'label': 'Research',
#   '_key': 'research',
#   'value': 'research',
#   '_type': 'tag'},
#  '_createdAt': '2023-12-21T03:32:31Z',
#  '_rev': 'CElEURHSNPsNPOAGksxZAd',
#  '_id': '1285aca9-4ef8-44f8-b176-f18c40b61808',
#  'title': 'Publications',
#  'flushTop': False,
#  'postSubjects': None,
#  'posts': [{'_type': 'post',
#    'cardPhoto': None,
#    'publishedOn': '2025-03-13T16:00:00.000Z',
#    'directories': [{'_type': 'tag',
#      'label': 'Research',
#      '_key': 'research',
#      'value': 'research'}],
#    'subjects': [{'_type': 'tag',
#      'label': 'Alignment',
#      '_key': 'alignment',
#      'value': 'alignment'},
#     {'_key': 'interpretability',
#      'value': 'interpretability',
#      '_type': 'tag',
#      'label': 'Interpretability'}],
# ...

# %%
import re

pattern = r'{\\"current\\":\\"([^"\\]+)\\",\\"_type\\":\\"slug\\"},\\"title\\":\\"([^"\\]+)\\",\\"cta\\":{\\"_type\\":\\"link\\",\\"text\\":\\"([^"\\]+)\\",\\"url\\":\\"([^"\\]+)\\"}}' 

# Example usage
text = script_tag.text
matches = re.findall(pattern, text)
for match in matches:
    current_value = match[0]
    title_value = match[1]
    text_value = match[2]
    url_value = match[3]
    print(f"Current: {current_value}")
    print(f"Title: {title_value}")
    print(f"Text: {text_value}")
    print(f"URL: {url_value}")
    print("\n--------------------------------\n")
# Out:
# Current: auditing-hidden-objectives
# Title: Auditing language models for hidden objectives
# Text: Read the paper
# URL: https://assets.anthropic.com/m/317564659027fb33/original/Auditing-Language-Models-for-Hidden-Objectives.pdf
#
# --------------------------------
#
# Current: the-anthropic-economic-index
# Title: The Anthropic Economic Index
# Text: Read the paper
# URL: http://arxiv.org/abs/2503.04761
#
# --------------------------------
#
# Current: clio
# Title: Clio: A system for privacy-preserving insights into real-world AI use
# Text: Read the paper
# URL: https://arxiv.org/abs/2412.13678
#
# --------------------------------
#
# Current: circuits-updates-august-2024
# Title: Circuits Updates – August 2024
# Text: Read Circuits Updates
# URL: https://transformer-circuits.pub/2024/august-update/index.html
#
# --------------------------------
#
# Current: reward-tampering
# Title: Sycophancy to subterfuge: Investigating reward tampering in language models
# ...
